# %%
import kauri as kr

# %% [markdown]
# ## Next tree with respect to lexicographic order

# %%
t = kr.Tree([[[[]],[]],[[]]])
kr.display(t)
print("Next tree:")
kr.display(next(t))
# Out:
# Next tree:

# %% [markdown]
# ## All trees of a given order

# %%
for n in range(6):
    print("Trees of order " + str(n) + ":")
    for t in kr.trees_of_order(n):
        kr.display(t)
# Out:
# Trees of order 0:
# Trees of order 1:
# Trees of order 2:
# Trees of order 3:
# Trees of order 4:
# Trees of order 5:

# %% [markdown]
# ## All trees up to a given order

# %%
print("All trees up to order 4:")
for t in kr.trees_up_to_order(4):
    kr.display(t)
# Out:
# All trees up to order 4:
